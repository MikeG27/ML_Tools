# %% [markdown]
# <h1 align = "center"> Outlier Detection </h1>

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.datasets import load_boston
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
# My packages :) 
from preprocessing.outliers import remove_outliers_IQR , remove_outliers_STD

# %%
boston = load_boston()
x = boston.data
y = boston.target
columns = boston.feature_names

# %%
#create the dataframe
boston_df = pd.DataFrame(boston.data)
boston_df.columns = columns
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
boston_df.shape
# Out:
# (506, 13)

# %%
boston_df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT
# count  506.000000
# mean    12.653063
# std      7.141062
# min      1.730000
# 25%      6.950000
# 50%     11.360000
# 75%     16.955000
# max     37.970000

# %%
_ = boston_df.hist(figsize=(15,15))

# %% [markdown]
# # Univariate outlier analysis

# %%
plt.figure()
boston_df.boxplot("CRIM")

# %% [markdown]
# Czy możemy zrobić multivariate analysis z boxplotami ?
# Tak jeżeli jedną osią będą zmienne ciągłe a drugą zmienne dyskretne

# %% [markdown]
# # Multivariate outlier analysis

# %% [markdown]
# #### Scatter plot

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(boston_df['INDUS'], boston_df['TAX'])
ax.set_xlabel('Proportion of non-retail business acres per town')
ax.set_ylabel('Full-value property-tax rate per $10,000')
plt.show()

# %% [markdown]
# Looking at the plot above, we can most of data points are lying bottom left side but there are points which are far from the population like top right corner.

# %% [markdown]
# # Wskaźniki do detekcji outlierów

# %% [markdown]
# ## Z-Score

# %% [markdown]
# The Z-score is the signed number of standard deviations by which the value of an observation or data point is above the mean value of what is being observed or measured.

# %% [markdown]
# The intuition behind Z-score is to describe any data point by finding their relationship with the Standard Deviation and Mean of the group of data points.** Z-score is finding the distribution of data where mean is 0 and standard deviation is 1 i.e. normal distribution**.

# %%
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(boston_df))
print(z)
# Out:
# [[0.41978194 0.28482986 1.2879095  ... 1.45900038 0.44105193 1.0755623 ]
#  [0.41733926 0.48772236 0.59338101 ... 0.30309415 0.44105193 0.49243937]
#  [0.41734159 0.48772236 0.59338101 ... 0.30309415 0.39642699 1.2087274 ]
#  ...
#  [0.41344658 0.48772236 0.11573841 ... 1.17646583 0.44105193 0.98304761]
#  [0.40776407 0.48772236 0.11573841 ... 1.17646583 0.4032249  0.86530163]
#  [0.41500016 0.48772236 0.11573841 ... 1.17646583 0.44105193 0.66905833]]

# %%
threshold = 3
print(np.where(z > threshold))
# Out:
# (array([ 55,  56,  57, 102, 141, 142, 152, 154, 155, 160, 162, 163, 199,
#        200, 201, 202, 203, 204, 208, 209, 210, 211, 212, 216, 218, 219,
#        220, 221, 222, 225, 234, 236, 256, 257, 262, 269, 273, 274, 276,
#        277, 282, 283, 283, 284, 347, 351, 352, 353, 353, 354, 355, 356,
#        357, 358, 363, 364, 364, 365, 367, 369, 370, 372, 373, 374, 374,
#        380, 398, 404, 405, 406, 410, 410, 411, 412, 412, 414, 414, 415,
#        416, 418, 418, 419, 423, 424, 425, 426, 427, 427, 429, 431, 436,
#        437, 438, 445, 450, 454, 455, 456, 457, 466]), array([ 1,  1,  1, 11, 12,  3,  3,  3,  3,  3,  3,  3,  1,  1,  1,  1,  1,
#         1,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  5,  3,  3,  1,  5,
#         5,  3,  3,  3,  3,  3,  3,  1,  3,  1,  1,  7,  7,  1,  7,  7,  7,
#         3,  3,  3,  3,  3,  5,  5,  5,  3,  3,  3, 12,  5, 12,  0,  0,  0,
#         0,  5,  0, 11, 11, 11, 12,  0, 12, 11, 11,  0, 11, 11, 11, 11, 11,
#        11,  0, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11]))

# %% [markdown]
# Don’t be confused by the results. The first array contains the list of row numbers and second array respective column numbers, which mean z[55][1] have a Z-score higher than 3.

# %%
print(z[55][1])
# Out:
# 3.375038763517309

# %% [markdown]
# So, the data point — 55th record on column ZN is an outlier.

# %% [markdown]
# # IQR score

# %%
Q1 = boston_df.quantile(0.25)
Q3 = boston_df.quantile(0.75)
IQR = Q3 - Q1
pd.DataFrame(IQR).T
# Out:
#        CRIM    ZN  INDUS  CHAS    NOX     RM    AGE      DI
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in eval(self, **kwargs)
#    3433
#    3434     def eval(self, **kwargs):
# -> 3435         return self.apply('eval', **kwargs)
#    3436
#    3437     def quantile(self, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3327
#    3328             kwargs['mgr'] = self
# -> 3329             applied = getattr(b, f)(**kwargs)
#    3330             result_blocks = _extend_blocks(applied, result_blocks)
#    3331
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in eval(self, func, other, errors, try_cast, mgr)
#    1396
#    1397                 raise TypeError('Could not compare [%s] with block values' %
# -> 1398                                 repr(other))
#    1399
#    1400         # transpose if needed
#
# TypeError: Could not compare [None] with block values

# %% [markdown]
# # Working with Outliers: Correcting, Removing

# %%
boston_df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT
# count  506.000000
# mean    12.653063
# std      7.141062
# min      1.730000
# 25%      6.950000
# 50%     11.360000
# 75%     16.955000
# max     37.970000

# %%
boston_df.shape
# Out:
# (506, 13)

# %%
df_boston_std = remove_outliers_STD(boston_df,treshold=2)
# Out:
# Removed 196 rows based on STD

# %%
df_boston_IQR = remove_outliers_IQR(boston_df,IQR_mul=2)
# Out:
# Removed 190 rows based on IQR

# %%
df_boston_std.describe()
# Out:
#              CRIM          ZN       INDUS   CHAS         NOX          RM  \
# count  310.000000  310.000000  310.000000  310.0  310.000000  310.000000
# mean     2.132210    6.193548   10.679581    0.0    0.540886    6.229945
# std      3.832224   13.135760    6.067903    0.0    0.091331    0.463915
# min      0.006320    0.000000    1.520000    0.0    0.389000    4.963000
# 25%      0.084020    0.000000    5.695000    0.0    0.464000    5.913250
# 50%      0.215690    0.000000    8.560000    0.0    0.524000    6.179000
# 75%      2.131840    0.000000   18.100000    0.0    0.603000    6.484750
# max     19.609100   55.000000   21.890000    0.0    0.770000    7.686000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  310.000000  310.000000  310.000000  310.000000  310.000000  310.000000
# mean    68.451935    3.794174    9.093548  397.645161   18.824194  381.490129
# std     25.622727    1.692771    8.324776  159.055332    1.838133   31.335028
# min     13.000000    1.169100    1.000000  193.000000   14.700000  179.360000
# 25%     45.925000    2.421250    4.000000  284.000000   17.800000  382.937500
# 50%     72.800000    3.422950    5.000000  311.000000   19.200000  393.470000
# 75%     92.825000    4.928375    8.000000  437.000000   20.200000  396.900000
# max    100.000000    7.980900   24.000000  666.000000   21.200000  396.900000
#
#             LSTAT
# count  310.000000
# mean    11.896742
# std      5.138612
# min      1.730000
# 25%      7.752500
# 50%     11.330000
# 75%     15.385000
# max     26.400000

# %%
df_boston_IQR.describe()
# Out:
#              CRIM          ZN       INDUS   CHAS         NOX          RM  \
# count  316.000000  316.000000  316.000000  316.0  316.000000  316.000000
# mean     1.278766    5.049051   10.566962    0.0    0.541486    6.251051
# std      2.436401   10.040867    6.563279    0.0    0.100686    0.549208
# min      0.006320    0.000000    1.380000    0.0    0.409000    4.903000
# 25%      0.084320    0.000000    5.190000    0.0    0.458000    5.894000
# 50%      0.182480    0.000000    8.140000    0.0    0.520000    6.167000
# 75%      0.775792    0.000000   18.100000    0.0    0.585000    6.495000
# max     10.233000   35.000000   27.740000    0.0    0.871000    8.069000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  316.000000  316.000000  316.000000  316.000000  316.000000  316.000000
# mean    67.426266    3.834836    7.465190  367.800633   18.559177  388.128259
# std     26.877185    1.775891    7.160433  148.286621    2.007133   12.504693
# min      2.900000    1.169100    1.000000  188.000000   13.000000  334.400000
# 25%     47.075000    2.386950    4.000000  276.000000   17.800000  385.797500
# 50%     72.600000    3.422950    5.000000  307.000000   18.900000  393.295000
# 75%     91.825000    5.214600    6.250000  407.750000   20.200000  396.900000
# max    100.000000    9.222900   24.000000  711.000000   21.200000  396.900000
#
#             LSTAT
# count  316.000000
# mean    11.835949
# std      5.805223
# min      1.730000
# 25%      7.525000
# 50%     10.570000
# 75%     14.810000
# max     34.410000
